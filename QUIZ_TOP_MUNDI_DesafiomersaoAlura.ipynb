# %% [markdown]
# <a href="https://colab.research.google.com/github/CarolisBlue/QUIZ-TOP-MUNDI/blob/main/QUIZ_TOP_MUNDI_DesafiomersaoAlura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install matplotlib

# %%
import google.generativeai as genai
from google.colab import userdata
api_key = userdata.get('APIKey')
genai.configure(api_key=api_key)

# %%
pip install pillow

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from PIL import Image

imagem = Image.open('/content/drive/MyDrive/TOP MUNDI MKT/LOGOS E FOTOS/LOGO.WITHE.2000x2000.png')

# %%
# Carregando as imagens
logo = Image.open('/content/drive/MyDrive/TOP MUNDI MKT/LOGOS E FOTOS/LOGO.WITHE.2000x2000.png')
ceo = Image.open('/content/drive/MyDrive/TOP MUNDI MKT/LOGOS E FOTOS/FOTO.BTM2023.2-SemFundo.png')

# Função para exibir a imagem
def exibir_imagem(imagem):
  plt.imshow(imagem)
  plt.axis('off')
  plt.show()

# Exibindo a logo da Top Mundi
exibir_imagem(logo)

# Pontuação para cada tipo de destino
pontos = {
    "sol_e_mar": 0,
    "aventura": 0,
    "campo_e_montanha": 0,
    "metropole": 0
}



print("Olá! \"Descubra seu próximo DESTINO!\" com a TOP MUNDI!")



# Pergunta 1
print("\nCom quem você irá viajar?")
print("a) Sozinho(a)")
print("b) Companheiro(a)")
print("c) Família")
print("d) Amigos")
resposta1 = input("Digite a letra da sua resposta: ")


# Pergunta 2
print("\nO que você prefere?")
print("a) Sol e Mar")
print("b) Aventura")
print("c) Campo e Montanha")
print("d) Metrópole")
resposta2 = input("Digite a letra da sua resposta: ")


# Pergunta 3
print("\nQual o seu estilo de viagem ideal?")
print("a) Relaxar e aproveitar a natureza")
print("b) Explorar lugares novos e ter contato com a cultura local")
print("c) Curtir a vida noturna e agito")
print("d) Uma mistura de tudo um pouco!")
resposta3 = input("Digite a letra da sua resposta: ")


# Pergunta 4
print("\nQual a sua faixa de orçamento?")
print("a) Econômico")
print("b) Intermediário")
print("c) Luxo")
print("d) Não importa o preço, quero aventura!")
resposta4 = input("Digite a letra da sua resposta: ")


# Pergunta 5
print("\nQual a época do ano ideal para você?")
print("a) Verão")
print("b) Inverno")
print("c) Qualquer época")
print("d) Depende do destino!")
resposta5 = input("Digite a letra da sua resposta: ")


# Lógica para adicionar pontos com base nas respostas
if resposta2 == "a":
  pontos["sol_e_mar"] += 2
elif resposta2 == "b":
  pontos["aventura"] += 2
elif resposta2 == "c":
  pontos["campo_e_montanha"] += 2
elif resposta2 == "d":
  pontos["metropole"] += 2

if resposta3 == "a":
  pontos["sol_e_mar"] += 1
  pontos["campo_e_montanha"] += 1
elif resposta3 == "b":
  pontos["aventura"] += 1
  pontos["metropole"] += 1
elif resposta3 == "c":
  pontos["metropole"] += 2
elif resposta3 == "d":
  pontos["sol_e_mar"] += 1
  pontos["aventura"] += 1
  pontos["campo_e_montanha"] += 1
  pontos["metropole"] += 1

# Adicionando lógica para as demais perguntas (similar ao exemplo acima)



# Exibindo a CEO da Top Mundi
exibir_imagem(ceo)

# Encontrando o(s) destino(s) com maior pontuação
destino_recomendado = max(pontos, key=pontos.get)

print("\nDe acordo com suas respostas, recomendamos:")

if destino_recomendado == "sol_e_mar":
  print("- Praias paradisíacas do Nordeste brasileiro, como: Fernando de Noronha, Jericoacoara, Porto de Galinhas e Trancoso.")
elif destino_recomendado == "aventura":
  print("- Bonito (MS), com suas águas cristalinas e grutas, trilhas e cachoeiras!")
  print("- Foz do Iguaçu (PR), para admirar as Cataratas e se aventurar em trilhas pela mata.")
elif destino_recomendado == "campo_e_montanha":
  print("- Campos do Jordão (SP), com paisagens montanhosas e clima europeu.")
  print("- Gramado (RS), com arquitetura charmosa e paisagens verdejantes.")
elif destino_recomendado == "metropole":
  print("- São Paulo (SP), com ampla variedade cultural, gastronômica e artística.")
  print("- Rio de Janeiro (RJ), com suas famosas praias, paisagens exuberantes e vida noturna agitada.")

print("\nA TOP MUNDI te leva para conhecer estes e outros destinos incríveis! Entre em contato conosco e planeje sua próxima viagem!")
# Out:
# Olá! "Descubra seu próximo DESTINO!" com a TOP MUNDI!
#
# Com quem você irá viajar?
# a) Sozinho(a)
# b) Companheiro(a)
# c) Família
# d) Amigos
# Digite a letra da sua resposta: b
#
# O que você prefere?
# a) Sol e Mar
# b) Aventura
# c) Campo e Montanha
# d) Metrópole
# Digite a letra da sua resposta: b
#
# Qual o seu estilo de viagem ideal?
# a) Relaxar e aproveitar a natureza
# b) Explorar lugares novos e ter contato com a cultura local
# c) Curtir a vida noturna e agito
# d) Uma mistura de tudo um pouco!
# Digite a letra da sua resposta: d
#
# Qual a sua faixa de orçamento?
# a) Econômico
# b) Intermediário
# c) Luxo
# d) Não importa o preço, quero aventura!
# Digite a letra da sua resposta: a
#
# Qual a época do ano ideal para você?
# a) Verão
# b) Inverno
# c) Qualquer época
# d) Depende do destino!
# Digite a letra da sua resposta: d
# De acordo com suas respostas, recomendamos:
# - Bonito (MS), com suas águas cristalinas e grutas, trilhas e cachoeiras!
# ...
